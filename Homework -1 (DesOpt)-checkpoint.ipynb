# %% [markdown]
# # Minimize the function

# %%
from scipy.optimize import minimize

fun = lambda x: (x[0] - x[1])**2 + (x[1] + x[2] - 2)**2 + (x[3] - 1)**2 + (x[4] - 1)**2
cons = ({'type': 'eq', 'fun' : lambda x: x[0] + 3*x[1]},
         {'type': 'eq', 'fun' : lambda x: x[2] + x[3] - 2*x[4]},
         {'type': 'eq', 'fun' : lambda x: x[1] - x[4]})
bnds = ((-10,10),(-10,10),(-10,10),(-10,10),(-10,10))
res = minimize (y, (1,1,1,1,1), method='SLSQP', bounds = bnds, constraints = cons)

# %%
res
# Out:
#      fun: 4.292682927753138
#      jac: array([-2.14639318, -3.12192583, -0.97553265, -0.97559553, -1.36584044])
#  message: 'Optimization terminated successfully'
#     nfev: 38
#      nit: 6
#     njev: 6
#   status: 0
#  success: True
#        x: array([-0.95123928,  0.31707976,  0.12195732,  0.5122022 ,  0.31707976])

# %%
from scipy.optimize import minimize

fun = lambda x: (x[0] - x[1])**2 + (x[1] + x[2] - 2)**2 + (x[3] - 1)**2 + (x[4] - 1)**2
cons = ({'type': 'eq', 'fun' : lambda x: x[0] + 3*x[1]},
         {'type': 'eq', 'fun' : lambda x: x[2] + x[3] - 2*x[4]},
         {'type': 'eq', 'fun' : lambda x: x[1] - x[4]})
bnds = ((-10,10),(-10,10),(-10,10),(-10,10),(-10,10))
res = minimize (y, (2,8,9,7,0), method='SLSQP', bounds = bnds, constraints = cons)

# %%
res
# Out:
#      fun: 4.292682927367433
#      jac: array([-2.14736259, -3.12104666, -0.97368407, -0.9763394 , -1.36579537])
#  message: 'Optimization terminated successfully'
#     nfev: 38
#      nit: 6
#     njev: 6
#   status: 0
#  success: True
#        x: array([-0.95122936,  0.31707645,  0.12193762,  0.51221529,  0.31707645])

# %%
from scipy.optimize import minimize

fun = lambda x: (x[0] - x[1])**2 + (x[1] + x[2] - 2)**2 + (x[3] - 1)**2 + (x[4] - 1)**2
cons = ({'type': 'eq', 'fun' : lambda x: x[0] + 3*x[1]},
         {'type': 'eq', 'fun' : lambda x: x[2] + x[3] - 2*x[4]},
         {'type': 'eq', 'fun' : lambda x: x[1] - x[4]})
bnds = ((-10,10),(-10,10),(-10,10),(-10,10),(-10,10))
res = minimize (y, (-8,-2,-7,-4,-9), method='SLSQP', bounds = bnds, constraints = cons)

# %%
res
# Out:
#      fun: 4.292682926875925
#      jac: array([-2.14519125, -3.12279868, -0.97760731, -0.97521627, -1.36600494])
#  message: 'Optimization terminated successfully'
#     nfev: 37
#      nit: 6
#     njev: 6
#   status: 0
#  success: True
#        x: array([-0.95121684,  0.31707228,  0.12195527,  0.51218929,  0.31707228])

# %% [markdown]
# The minimal function value and the solution do not change(only slight fluctuations), after changing the initial guesses.
